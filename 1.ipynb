# %%
print(1)
# Out:
# 1

# %%
from debate import graph,DebateState

print(graph.invoke(DebateState(question="Should Lgbtq rights be Legalized?")))
# Out:
# [Input] Question: Should Lgbtq rights be Legalized?
#
# [Republican]: As a Republican, I believe that traditional marriage and values should be upheld, and while I respect individual freedoms, I do not support the legalization of LGBTQ rights that infringe upon the rights of others, such as religious freedom. The push for LGBTQ rights often leads to the erosion of First Amendment protections and the imposition of radical ideologies on our children. We must prioritize the preservation of our nation's founding values and principles.
#
# ...

# %%
import sys
print(sys.executable)
# Out:
# d:\expense-tracker\.venv\Scripts\python.exe
